# %%
display(dbutils.fs.ls("dbfs:/databricks-datasets/COVID/ESRI_hospital_beds/Definitive_Healthcare__USA_Hospital_Beds_2020_03_30.csv"))

# %%
from pyspark.sql.functions import sum
df = spark.read.csv("dbfs:/databricks-datasets/COVID/ESRI_hospital_beds/Definitive_Healthcare__USA_Hospital_Beds_2020_03_30.csv", header=True, inferSchema= True)
grouped_df = df.groupBy("HOSPITAL_TYPE").agg(sum("NUM_STAFFED_BEDS").alias("total_beds"), sum("NUM_ICU_BEDS").alias("total_icu_beds"))
display(grouped_df)
